# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Store CSV into DataFrame

# %%
csv_file1 = "../Resources/winemag-data130.csv"
csv_file2 = "../Resources/winemag-data150.csv"
wine_data_data130_df = pd.read_csv(csv_file1, encoding="UTF-8")
wine_data_data150_df = pd.read_csv(csv_file2)
wine_data_data130_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
wine_data_data150_df["variety"].unique
# Out:
# <bound method Series.unique of 0         Cabernet Sauvignon
# 1              Tinta de Toro
# 2            Sauvignon Blanc
# 3                 Pinot Noir
# 4         Provence red blend
#                  ...
# 150925           White Blend
# 150926       Champagne Blend
# 150927           White Blend
# 150928       Champagne Blend
# 150929          Pinot Grigio
# Name: variety, Length: 150930, dtype: object>

# %%
wine_data_data130_df.loc[wine_data_data130_df["variety"]=="Heitz has made this stellar rosÃ© from the rare Grignolino grape since 1961. Ruby grapefruit-red, it's sultry with strawberry, watermelon, orange zest and salty spice flavor, highlighted with vibrant floral aromas.",:]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
# Create a filtered dataframe from specific columns
premises_cols= ["country","province","region_1","winery","designation","variety","title","points","price","description",]
wine_130_ts= wine_data_data130_df[premises_cols].copy()

# Rename the column headers
wine_130_ts=wine_130_ts.rename(columns={"description":"review",
                                        "designation":"vineyard",
                                        "region_1":"region"
                                       })


wine_130_ts.head()
# Out:
#     country           province               region               winery  \
# 0     Italy  Sicily & Sardinia                 Etna              Nicosia
# 1  Portugal              Douro                  NaN  Quinta dos Avidagos
# 2        US             Oregon    Willamette Valley            Rainstorm
# 3        US           Michigan  Lake Michigan Shore           St. Julian
# 4        US             Oregon    Willamette Valley         Sweet Cheeks
#
#                              vineyard         variety  \
# 0                        Vulkà Bianco     White Blend
# 1                            Avidagos  Portuguese Red
# 2                                 NaN      Pinot Gris
# 3                Reserve Late Harvest        Riesling
# 4  Vintner's Reserve Wild Child Block      Pinot Noir
#
#                                                title  points  price  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)      87    NaN
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)      87   15.0
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      87   14.0
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...      87   13.0
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      87   65.0
#
#                                               review
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...

# %%
# Create a filtered dataframe from specific columns
premises_cols2= ["country","province","region_1","winery","designation","variety","points","price","description"]
wine_150_ts= wine_data_data150_df[premises_cols2].copy()

# Rename the column headers
wine_150_ts=wine_150_ts.rename(columns={"description":"review",
                                        "designation":"vineyard",
                                        "region_1":"region"
                                       })

wine_150_ts.head()
# Out:
#   country        province             region                   winery  \
# 0      US      California        Napa Valley                    Heitz
# 1   Spain  Northern Spain               Toro  Bodega Carmen Rodríguez
# 2      US      California     Knights Valley                 Macauley
# 3      US          Oregon  Willamette Valley                    Ponzi
# 4  France        Provence             Bandol     Domaine de la Bégude
#
#                                vineyard             variety  points  price  \
# 0                     Martha's Vineyard  Cabernet Sauvignon      96  235.0
# 1  Carodorum Selección Especial Reserva       Tinta de Toro      96  110.0
# 2         Special Selected Late Harvest     Sauvignon Blanc      96   90.0
# 3                               Reserve          Pinot Noir      96   65.0
# 4                            La Brûlade  Provence red blend      95   66.0
#
#                                               review
# 0  This tremendous 100% varietal wine hails from ...
# 1  Ripe aromas of fig, blackberry and cassis are ...
# 2  Mac Watson honors the memory of a wine once ma...
# 3  This spent 20 months in 30% new French oak, an...
# 4  This is the top wine from La Bégude, named aft...

# %%
merged_df=wine_130_ts.merge(wine_150_ts, on="review", how="left")

pd.set_option('display.max_columns', None)
merged_df
# Out:
#        country_x         province_x             region_x  \
# 0          Italy  Sicily & Sardinia                 Etna
# 1       Portugal              Douro                  NaN
# 2             US             Oregon    Willamette Valley
# 3             US           Michigan  Lake Michigan Shore
# 4             US             Oregon    Willamette Valley
# ...          ...                ...                  ...
# 151627   Germany              Mosel                  NaN
# 151628        US             Oregon               Oregon
# 151629    France             Alsace               Alsace
# 151630    France             Alsace               Alsace
# 151631    France             Alsace               Alsace
#
#                                         winery_x  \
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 151627  Dr. H. Thanisch (Erben Müller-Burggraef)
# 151628                                  Citation
# 151629                           Domaine Gresser
# 151630                      Domaine Marcel Deiss
# 151631                          Domaine Schoffit
#
#                                     vineyard_x       variety_x  \
# 0                                 Vulkà Bianco     White Blend
# 1                                     Avidagos  Portuguese Red
# 2                                          NaN      Pinot Gris
# 3                         Reserve Late Harvest        Riesling
# 4           Vintner's Reserve Wild Child Block      Pinot Noir
# ...                                        ...             ...
# 151627  Brauneberger Juffer-Sonnenuhr Spätlese        Riesling
# 151628                                     NaN      Pinot Noir
# 151629                                   Kritt  Gewürztraminer
# 151630                                     NaN      Pinot Gris
# 151631           Lieu-dit Harth Cuvée Caroline  Gewürztraminer
#
#                                                     title  points_x  price_x  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)        87      NaN
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)        87     15.0
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)        87     14.0
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        87     13.0
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...        87     65.0
# ...                                                   ...       ...      ...
# 151627  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        90     28.0
# 151628                  Citation 2004 Pinot Noir (Oregon)        90     75.0
# 151629  Domaine Gresser 2013 Kritt Gewurztraminer (Als...        90     30.0
# 151630      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)        90     32.0
# 151631  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...        90     21.0
#
#                                                    review country_y  \
# 0       Aromas include tropical fruit, broom, brimston...       NaN
# 1       This is ripe and fruity, a wine that is smooth...       NaN
# 2       Tart and snappy, the flavors of lime flesh and...       NaN
# 3       Pineapple rind, lemon pith and orange blossom ...       NaN
# 4       Much like the regular bottling from 2012, this...       NaN
# ...                                                   ...       ...
# 151627  Notes of honeysuckle and cantaloupe sweeten th...       NaN
# 151628  Citation is given as much as a decade of bottl...       NaN
# 151629  Well-drained gravel soil gives this wine its c...       NaN
# 151630  A dry style of Pinot Gris, this is crisp with ...       NaN
# 151631  Big, rich and off-dry, this is powered by inte...       NaN
#
#        province_y region_y winery_y vineyard_y variety_y  points_y  price_y
# 0             NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 1             NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 2             NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 3             NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 4             NaN      NaN      NaN        NaN       NaN       NaN      NaN
# ...           ...      ...      ...        ...       ...       ...      ...
# 151627        NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 151628        NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 151629        NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 151630        NaN      NaN      NaN        NaN       NaN       NaN      NaN
# 151631        NaN      NaN      NaN        NaN       NaN       NaN      NaN
#
# [151632 rows x 18 columns]
