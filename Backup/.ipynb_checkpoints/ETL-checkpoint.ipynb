# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Store CSV into DataFrame

# %%
csv_file1 = "../Resources/winemag-data130.csv"
csv_file2 = "../Resources/winemag-data150.csv"
wine_data_data130_df = pd.read_csv(csv_file1, encoding="UTF-8")
wine_data_data150_df = pd.read_csv(csv_file2)

# %%
wine_data_data130_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_data_data130_df.shape
# Out:
# (129971, 14)

# %%
wine_data_data150_df.shape
# Out:
# (150930, 11)

# %%
wine_data_data150_df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
wine_data_data150_df["variety"].unique
# Out:
# <bound method Series.unique of 0         Cabernet Sauvignon
# 1              Tinta de Toro
# 2            Sauvignon Blanc
# 3                 Pinot Noir
# 4         Provence red blend
#                  ...
# 150925           White Blend
# 150926       Champagne Blend
# 150927           White Blend
# 150928       Champagne Blend
# 150929          Pinot Grigio
# Name: variety, Length: 150930, dtype: object>

# %%
wine_data_data150_df.loc[wine_data_data150_df["variety"]=="Rosé",:]
# Out:
#         Unnamed: 0    country  \
# 20              20         US
# 111            111  Argentina
# 117            117     France
# 139            139     France
# 140            140     France
# ...            ...        ...
# 150247      150247      Chile
# 150489      150489         US
# 150527      150527         US
# 150536      150536         US
# 150891      150891      Chile
#
#                                               description  \
# 20      Heitz has made this stellar rosé from the rare...
# 111     This copper-tinted rosé of Pinot Noir smells l...
# 117     This pale pink-grey colored wine is a blend of...
# 139     Attractive fruity tones of red currant, raspbe...
# 140     Lightly structured, this is a balanced, ripe w...
# ...                                                   ...
# 150247  Pretty interesting and solid as Chilean rose g...
# 150489  Tart green-apple flavors are joined on the pal...
# 150527  Peach and faint berry flavors in a light, cris...
# ...

# %%
merged_df=wine_data_data130_df.merge(wine_data_data150_df, on="description", how="inner")
merged_df.shape
merged_df
# Out:
#        Unnamed: 0_x  country_x  \
# 0                29         US
# 1                29         US
# 2                30     France
# 3                30     France
# 4                31      Italy
# ...             ...        ...
# 73566        129936     France
# 73567        129937    Austria
# 73568        129938  Argentina
# 73569        129939    Austria
# 73570        129940         US
#
#                                              description  \
# 0      Clarksburg is becoming a haven for Chenin Blan...
# 1      Clarksburg is becoming a haven for Chenin Blan...
# 2      Red cherry fruit comes laced with light tannin...
# 3      Red cherry fruit comes laced with light tannin...
# 4      Merlot and Nero d'Avola form the base for this...
# ...                                                  ...
# 73566  A blend from several premier cru vineyards in ...
# 73567  Smooth, creamy aromas are followed by a rich, ...
# 73568  Compared to the regular 2006 Malbec from Chaka...
# ...

# %%
merged_df.loc[merged_df["title"]].isnull()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-d082f21a7524> in <module>
# ----> 1 merged_df.loc[merged_df["title"]].isnull()
#
# c:\users\intel nuc\onedrive\++tec data analytics bootcamp\bootcamp\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# c:\users\intel nuc\onedrive\++tec data analytics bootcamp\bootcamp\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
#    1101             # nested tuple slicing
#
# ...

# %%
merged_df.iloc[73566, 2]
# Out:
# 'A blend from several premier cru vineyards in Pommard, here is a wine that exhibits just the right firm but dusty tannins of the appellation. But because it is 2005, the natural exuberance of the fruit is also there, lively red berries under the dry structure. It needs some aging, but already the richness is there, along with a smoky aftertaste.'
